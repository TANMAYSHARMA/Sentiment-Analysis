# %%
# Mounting Google Drive to read file
from google.colab import drive
drive.mount('/content/drive')

# Change directory
# %cd /content/drive/My\ Drive/Colab\ Notebooks/IDS576/Project
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/IDS576/Project
#  Attention.ipynb		       Preprocessing.ipynb
#  attention.pt			       RNN_Accuracy.png
#  attnRNN.log			       RNN_LearningCurve.png
#  BaseModel.ipynb		       RNN_LearningCurve_test.png
#  ErrorAnalysis.ipynb		       run_attnRNN.sh
#  GRU.log			       run_GRU.sh
#  GRU.pt				       run_LSTM.sh
#  Hotel_Reviews.csv		       run_vRNN.sh
#  HotelReviews.ipynb		       saved_weights_attn.pt
# ...

# %%
# !chmod +x *.sh
# !ls -la
# Out:
# total 413528
# -rw------- 1 root root    188691 Apr 13 15:21  Attention.ipynb
# -rw------- 1 root root   9950786 Apr 23 16:14  attention.pt
# -rw------- 1 root root    207347 Apr 23 16:14  attnRNN.log
# -rw------- 1 root root     17961 Apr 16 03:27  BaseModel.ipynb
# -rw------- 1 root root     15906 Apr 20 20:12  ErrorAnalysis.ipynb
# -rw------- 1 root root     27463 Mar 29 00:42  GRU.log
# -rw------- 1 root root   4769859 Mar 29 00:42  GRU.pt
# -rw------- 1 root root 238154765 Mar 22 23:33  Hotel_Reviews.csv
# -rw------- 1 root root    284295 Mar 30 22:03  HotelReviews.ipynb
# -rw------- 1 root root  95615455 Apr 15 19:27  hotel_reviews_processed.csv
# -rw------- 1 root root  13824157 Apr 15 19:10  hotel_reviews_processed_old.csv
# -rw------- 1 root root    517998 Apr 23 19:31  IDS576_Project_2.ipynb
# -rw------- 1 root root    518034 Apr 23 19:59  IDS576_Project.ipynb
# -rw------- 1 root root    215009 Apr 16 03:25  LSTM.log
# -rw------- 1 root root  10756221 Apr 16 03:25  LSTM.pt
# ...

# %%
# !bash run_vRNN.sh
# Out:
# Train Epoch: 1 [0/519964 (0%)]	Train Loss: 0.713882	Testing Loss: 0.000870	Testing Acc: 44.560001373291016
# Train Epoch: 1 [10000/519964 (2%)]	Train Loss: 0.868204	Testing Loss: 0.000708	Testing Acc: 48.18000030517578
# Train Epoch: 1 [20000/519964 (4%)]	Train Loss: 0.817775	Testing Loss: 0.000734	Testing Acc: 46.21999740600586
# Train Epoch: 1 [30000/519964 (6%)]	Train Loss: 0.692569	Testing Loss: 0.000702	Testing Acc: 52.0
# Train Epoch: 1 [40000/519964 (8%)]	Train Loss: 0.730464	Testing Loss: 0.000701	Testing Acc: 48.099998474121094
# Train Epoch: 1 [50000/519964 (10%)]	Train Loss: 0.890055	Testing Loss: 0.000699	Testing Acc: 52.119998931884766
# Train Epoch: 1 [60000/519964 (12%)]	Train Loss: 0.718895	Testing Loss: 0.000697	Testing Acc: 52.31999588012695
# Train Epoch: 1 [70000/519964 (13%)]	Train Loss: 0.815244	Testing Loss: 0.000699	Testing Acc: 50.63999938964844
# Train Epoch: 1 [80000/519964 (15%)]	Train Loss: 0.775090	Testing Loss: 0.000694	Testing Acc: 52.099998474121094
# ...

# %%
# !bash run_GRU.sh
# Out:
# Train Epoch: 1 [0/70000 (0%)]	Train Loss: 0.688542	Testing Loss: 0.015630	Testing Acc: 44.375
# Train Epoch: 1 [1280/70000 (2%)]	Train Loss: 0.665447	Testing Loss: 0.006052	Testing Acc: 44.375
